# %% [markdown]
# # COMP3115 Lab2 Tutorial: Pandas; Matplotlib

# %% [markdown]
# ## 1. Introduction to Pandas

# %% [markdown]
# Pandas is an open source library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language.

# %% [markdown]
# ### Titanic Dataset
# - Provides information on the fate of passengers on the Titanic, summarized according to economic status (class), sex, age and survival.
# - Below are the features provided in the dataset.
#   - Passenger Id: and id given to each traveler on the boat
#   - Survived: the passenger survived(1) or dead(0)
#   - Pclass: the passenger class. It has three possible values: 1,2,3 (first, second and third class)
#   - The Name of the passenger
#   - Sex: gender of the passenger
#   - Age: age of the passenger
#   - SibSp: number of siblings and spouses traveling with the passenger
#   - Parch: number of parents and children traveling with the passenger
#   - The ticket number
#   - The ticket Fare
#   - The cabin number
#   - The embarkation. This describe three possible areas of the Titanic from which the people embark. Three possible values S,C,Q
# - Learn more about the titanic dataset: [Kaggle.com](https://www.kaggle.com/c/titanic/data)
# - We will use the training dataset, train.csv, to demonstrate how to use pandas

# %% [markdown]
# ### Import the pandas library

# %%
import pandas as pd

# %% [markdown]
# ### Load Data into Pandas DataFrame
# Pandas DataFrames are two-deminesional labeled data structures with columns of potentially different types. In plain terms, think of a DataFrame as a table of data, i.e. a single set of formatted two-dimensional data, with the following characteristics:
# - There can be multiple rows and columns in the data
# - Each row represents a sample of data
# - Each column contains a different variable that describes the samples
# - The data in every column is usually the same type of data – e.g. numbers, strings, dates

# %%
# load CSV files into Python to create Pandas Dataframes using the read_csv function 
# syntax: pd.read_csv('file path', 
#                      header = 'Row number to use as the column names' or None, 
#                      sep = 'delimiter')
#

df =  pd.read_csv('titanic.csv', header=0, sep=',')
#df.loc[10:20, :]
#df.iloc[0:10, :]
#print(df.to_string()) #Render a DataFrame to a console-friendly tabular output.

# %%
#pd.set_option('display.max_columns', None) #If max_cols is exceeded, switch to truncate view. Depending on large_repr, objects are either centrally truncated or printed as a summary view. ‘None’ value means unlimited.
pd.set_option("display.max_rows", None) #If max_rows is exceeded, switch to truncate view. Depending on large_repr, objects are either centrally truncated or printed as a summary view. ‘None’ value means unlimited.
#df

# %% [markdown]
# ### Exploring the data

# %%
# check the size of the dataframe
df.shape
# Out:
# (891, 12)

# %% [markdown]
# There are 891 rows and 12 columns in the dataframe

# %%
# chek if the data loaded properly

# show the first few rows, 5 rows by defalut
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# show the first 2 rows
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
# show the last few rows, 5 by default
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 881    male  33.0      0      0            349257   7.8958   NaN        S
# 882  female  22.0      0      0              7552  10.5167   NaN        S
# 883    male  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884    male  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 885  female  39.0      0      5            382652  29.1250   NaN        Q
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q

# %%
# show the last 3 rows
df.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# set the index of the dataframe to Passengerid
df = df.set_index('PassengerId')
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
# display a summary of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %% [markdown]
# As we can see in the output, the summary includes list of all columns with their data types and the number of non-null values in each column. we also have the value of rangeindex provided for the index axis.

# %%
# get basic statistics on numerical columns in the dataframe
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# check if any missing value in the dataframe
df.isnull().values.any() #.any() Test whether any array element along a given axis evaluates to True.
# Out:
# True

# %%
# check if any missing value in each column
df.isnull().any()
# Out:
# Survived    False
# Pclass      False
# Name        False
# Sex         False
# Age          True
# SibSp       False
# Parch       False
# Ticket      False
# Fare        False
# Cabin        True
# Embarked     True
# dtype: bool

# %%
# count the missing value in each column
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
# count the missing value in the dtaframe (method 1)
df.isnull().sum().sum()
# Out:
# 866

# %%
# count the missing value in the dtaframe (method 2)
df.isnull().values.sum()
# Out:
# 866

# %% [markdown]
# ### Deleteing rows and columns

# %%
# get all the column names
df.columns.values
# Out:
# array(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %%
# delete the Carbin column
df = df.drop('Cabin', axis = 1)   #axis = 1 for columns 
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500        S
# 2                1      0          PC 17599  71.2833        C
# 3                0      0  STON/O2. 3101282   7.9250        S
# 4                1      0            113803  53.1000        S
# 5                0      0            373450   8.0500        S

# %%
# delete the row with index 1
df = df.drop(1, axis = 0)   #axis = 0 for rows
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
#
#              SibSp  Parch            Ticket     Fare Embarked
# PassengerId
# 2                1      0          PC 17599  71.2833        C
# 3                0      0  STON/O2. 3101282   7.9250        S
# 4                1      0            113803  53.1000        S
# 5                0      0            373450   8.0500        S
# 6                0      0            330877   8.4583        Q

# %%
# delete the rows where at least one element is missing
df = df.dropna()
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 7                   0       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
#
#              SibSp  Parch            Ticket     Fare Embarked
# PassengerId
# 2                1      0          PC 17599  71.2833        C
# 3                0      0  STON/O2. 3101282   7.9250        S
# 4                1      0            113803  53.1000        S
# 5                0      0            373450   8.0500        S
# 7                0      0             17463  51.8625        S

# %%
# check if any missing values in the dataframe
df.isnull().values.any()
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 711 entries, 2 to 891
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  711 non-null    int64
#  1   Pclass    711 non-null    int64
#  2   Name      711 non-null    object
#  3   Sex       711 non-null    object
#  4   Age       711 non-null    float64
#  5   SibSp     711 non-null    int64
#  6   Parch     711 non-null    int64
#  7   Ticket    711 non-null    object
#  8   Fare      711 non-null    float64
#  9   Embarked  711 non-null    object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 61.1+ KB

# %% [markdown]
# ### Selecting and Manipulating Data

# %% [markdown]
# ### Selecting columns
# There are three main methods of selecting columns:
# - using a dot notation, e.g. `df.column_name`
# - using square braces and the name of the column as a strng, e.g. `df['column_name']`
# - using number indexing and the iloc selecter, e.g. `df.iloc[:, column_number]`

# %%
# get all the column names
df.columns.values
# Out:
# array(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Embarked'], dtype=object)

# %%
# get the Name column (method 1)
df.Name.head()
# Out:
# PassengerId
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                               Heikkinen, Miss. Laina
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                             Allen, Mr. William Henry
# 7                              McCarthy, Mr. Timothy J
# Name: Name, dtype: object

# %%
# get the Name column (method 2)
df['Name'].head()
# Out:
# PassengerId
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                               Heikkinen, Miss. Laina
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                             Allen, Mr. William Henry
# 7                              McCarthy, Mr. Timothy J
# Name: Name, dtype: object

# %%
# get the Name column (method 3)
df.iloc[:, 2].head()  #selecting all rows in column 2, 2 is the column number of the Name column
# Out:
# PassengerId
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                               Heikkinen, Miss. Laina
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                             Allen, Mr. William Henry
# 7                              McCarthy, Mr. Timothy J
# Name: Name, dtype: object

# %%
type(df.iloc[:, 2])
# Out:
# pandas.core.series.Series

# %%
# get the Name column (method 3)
df.iloc[:, [2]].head()  #retrun a dataframe if the input coulum number is a list
# Out:
#                                                           Name
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                       Heikkinen, Miss. Laina
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                                     Allen, Mr. William Henry
# 7                                      McCarthy, Mr. Timothy J

# %%
type(df.iloc[:, [2]])
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 7                   0       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
#
#              SibSp  Parch            Ticket     Fare Embarked
# PassengerId
# 2                1      0          PC 17599  71.2833        C
# 3                0      0  STON/O2. 3101282   7.9250        S
# 4                1      0            113803  53.1000        S
# 5                0      0            373450   8.0500        S
# 7                0      0             17463  51.8625        S

# %%
# get multiple columns
# using square-brace selection with a list of column names 
df[['Sex', 'Age', 'Ticket']].head()
# Out:
#                 Sex   Age            Ticket
# PassengerId
# 2            female  38.0          PC 17599
# 3            female  26.0  STON/O2. 3101282
# 4            female  35.0            113803
# 5              male  35.0            373450
# 7              male  54.0             17463

# %%
# get multiple columns
# using numberic indexing with the iloc selector and a list of column numbers
df.iloc[:, [3, 4, 7]].head()
# Out:
#                 Sex   Age            Ticket
# PassengerId
# 2            female  38.0          PC 17599
# 3            female  26.0  STON/O2. 3101282
# 4            female  35.0            113803
# 5              male  35.0            373450
# 7              male  54.0             17463

# %%
# get multiple columns
# using numberic indexing with the iloc selector and a list of column numbers
df.iloc[:, 4:8].head() # equivalent to df.iloc[:, [4,5,6,7,]].head()
# Out:
#               Age  SibSp  Parch            Ticket
# PassengerId
# 1            22.0      1      0         A/5 21171
# 2            38.0      1      0          PC 17599
# 3            26.0      0      0  STON/O2. 3101282
# 4            35.0      1      0            113803
# 5            35.0      0      0            373450

# %% [markdown]
# ### Selecting rows
# There are three main methods of selecting rows:
# - using the iloc selecter, e.g. `df.iloc[row_number, :]`
# - using the loc sector, e.g. `df.loc[row number, :]`, but this is only applicably if "index" has been set on the dataframe
# - using boolean/conditional lookup statements, e.g. `df[df['column_name'] == 'value']`

# %%
df.head(10)
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
#
#              SibSp  Parch            Ticket     Fare Embarked
# PassengerId
# 2                1      0          PC 17599  71.2833        C
# 3                0      0  STON/O2. 3101282   7.9250        S
# 4                1      0            113803  53.1000        S
# 5                0      0            373450   8.0500        S
# 7                0      0             17463  51.8625        S
# 8                3      1            349909  21.0750        S
# 9                0      2            347742  11.1333        S
# 10               1      0            237736  30.0708        C
# 11               1      1           PP 9549  16.7000        S
# 12               0      0            113783  26.5500        S

# %%
# get row 6 using iloc, start from 0
df.iloc[[5], :]
# Out:
#              Survived  Pclass                            Name   Sex  Age  \
# PassengerId
# 8                   0       3  Palsson, Master. Gosta Leonard  male  2.0
#
#              SibSp  Parch  Ticket    Fare Embarked
# PassengerId
# 8                3      1  349909  21.075        S

# %%
# get row 5 to 9 using iloc
df.iloc[5:10, :]
# Out:
#              Survived  Pclass  \
# PassengerId
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
#
#              SibSp  Parch   Ticket     Fare Embarked
# PassengerId
# 8                3      1   349909  21.0750        S
# 9                0      2   347742  11.1333        S
# 10               1      0   237736  30.0708        C
# 11               1      1  PP 9549  16.7000        S
# 12               0      0   113783  26.5500        S

# %%
# get row with index 10
df.loc[[10], :]
# Out:
#              Survived  Pclass                                 Name     Sex  \
# PassengerId
# 10                  1       2  Nasser, Mrs. Nicholas (Adele Achem)  female
#
#               Age  SibSp  Parch  Ticket     Fare Embarked
# PassengerId
# 10           14.0      1      0  237736  30.0708        C

# %%
# get row with index 1 to 10 using loc
df.loc[1:10, :]
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
#
#              SibSp  Parch            Ticket     Fare Embarked
# PassengerId
# 2                1      0          PC 17599  71.2833        C
# 3                0      0  STON/O2. 3101282   7.9250        S
# 4                1      0            113803  53.1000        S
# 5                0      0            373450   8.0500        S
# 7                0      0             17463  51.8625        S
# 8                3      1            349909  21.0750        S
# 9                0      2            347742  11.1333        S
# 10               1      0            237736  30.0708        C

# %%
# get all rows of female
df[df['Sex'] == 'female']
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 15                  0       3
# 16                  1       2
# 19                  0       3
# 23                  1       3
# 25                  0       3
# 26                  1       3
# 39                  0       3
# 40                  1       3
# 41                  0       3
# 42                  0       2
# 44                  1       2
# 45                  1       3
# 50                  0       3
# 53                  1       1
# 54                  1       2
# 57                  1       2
# 59                  1       2
# 67                  1       2
# 69                  1       3
# 72                  0       3
# 80                  1       3
# 85                  1       2
# 86                  1       3
# 89                  1       1
# 99                  1       2
# 101                 0       3
# 107                 1       3
# 112                 0       3
# 114                 0       3
# 115                 0       3
# 120                 0       3
# 124                 1       2
# 133                 0       3
# 134                 1       2
# 137                 1       1
# 142                 1       3
# 143                 1       3
# 148                 0       3
# 152                 1       1
# 157                 1       3
# 162                 1       2
# 168                 0       3
# 173                 1       3
# 178                 0       1
# 185                 1       3
# 191                 1       2
# 193                 1       3
# 195                 1       1
# 196                 1       1
# 200                 0       2
# 206                 0       3
# 209                 1       3
# 212                 1       2
# 216                 1       1
# 217                 1       3
# 219                 1       1
# 231                 1       1
# 234                 1       3
# 856              0      1            392091    9.3500        S
# 857              1      1             36928  164.8667        S
# 859              0      3              2666   19.2583        C
# 863              0      0             17466   25.9292        S
# 866              0      0            236852   13.0000        S
# 867              1      0     SC/PARIS 2149   13.8583        C
# 872              1      1             11751   52.5542        S
# 875              1      0         P/PP 3381   24.0000        C
# 876              0      0              2667    7.2250        C
# 880              0      1             11767   83.1583        C
# 881              0      1            230433   26.0000        S
# 883              0      0              7552   10.5167        S
# 886              0      5            382652   29.1250        Q
# 888              0      0            112053   30.0000        S

# %%
# get all rows with age greater than 60
df[df['Age'] > 60]
# Out:
#              Survived  Pclass                                  Name     Sex  \
# PassengerId
# 34                  0       2                 Wheadon, Mr. Edward H    male
# 55                  0       1        Ostby, Mr. Engelhart Cornelius    male
# 97                  0       1             Goldschmidt, Mr. George B    male
# 117                 0       3                  Connors, Mr. Patrick    male
# 171                 0       1             Van der hoef, Mr. Wyckoff    male
# 253                 0       1             Stead, Mr. William Thomas    male
# 276                 1       1     Andrews, Miss. Kornelia Theodosia  female
# 281                 0       3                      Duane, Mr. Frank    male
# 327                 0       3             Nysveen, Mr. Johan Hansen    male
# 439                 0       1                     Fortune, Mr. Mark    male
# 457                 0       1             Millet, Mr. Francis Davis    male
# 484                 1       3                Turkula, Mrs. (Hedwig)  female
# 494                 0       1               Artagaveytia, Mr. Ramon    male
# 546                 0       1          Nicholson, Mr. Arthur Ernest    male
# 556                 0       1                    Wright, Mr. George    male
# 571                 1       2                    Harris, Mr. George    male
# 626                 0       1                 Sutton, Mr. Frederick    male
# 631                 1       1  Barkworth, Mr. Algernon Henry Wilson    male
# 673                 0       2           Mitchell, Mr. Henry Michael    male
# 746                 0       1          Crosby, Capt. Edward Gifford    male
# 852                 0       3                   Svensson, Mr. Johan    male
#
#               Age  SibSp  Parch       Ticket      Fare Embarked
# PassengerId
# 34           66.0      0      0   C.A. 24579   10.5000        S
# 55           65.0      0      1       113509   61.9792        C
# 97           71.0      0      0     PC 17754   34.6542        C
# 117          70.5      0      0       370369    7.7500        Q
# 171          61.0      0      0       111240   33.5000        S
# 253          62.0      0      0       113514   26.5500        S
# 276          63.0      1      0        13502   77.9583        S
# 281          65.0      0      0       336439    7.7500        Q
# 327          61.0      0      0       345364    6.2375        S
# 439          64.0      1      4        19950  263.0000        S
# 457          65.0      0      0        13509   26.5500        S
# 484          63.0      0      0         4134    9.5875        S
# 494          71.0      0      0     PC 17609   49.5042        C
# 546          64.0      0      0          693   26.0000        S
# 556          62.0      0      0       113807   26.5500        S
# 571          62.0      0      0  S.W./PP 752   10.5000        S
# 626          61.0      0      0        36963   32.3208        S
# 631          80.0      0      0        27042   30.0000        S
# 673          70.0      0      0   C.A. 24580   10.5000        S
# 746          70.0      1      1    WE/P 5735   71.0000        S
# 852          74.0      0      0       347060    7.7750        S

# %%
# get all rows of female with age greater than 60
df[(df['Sex']=='female') & (df['Age'] > 60)]
# Out:
#              Survived  Pclass                               Name     Sex  \
# PassengerId
# 276                 1       1  Andrews, Miss. Kornelia Theodosia  female
# 484                 1       3             Turkula, Mrs. (Hedwig)  female
#
#               Age  SibSp  Parch Ticket     Fare Embarked
# PassengerId
# 276          63.0      1      0  13502  77.9583        S
# 484          63.0      0      0   4134   9.5875        S

# %%
# get all rows with age less than 1 or  age greater than 70
df[(df['Age'] < 1 ) | (df['Age'] > 70)]
# Out:
#              Survived  Pclass                                  Name     Sex  \
# PassengerId
# 79                  1       2         Caldwell, Master. Alden Gates    male
# 97                  0       1             Goldschmidt, Mr. George B    male
# 117                 0       3                  Connors, Mr. Patrick    male
# 306                 1       1        Allison, Master. Hudson Trevor    male
# 470                 1       3         Baclini, Miss. Helene Barbara  female
# 494                 0       1               Artagaveytia, Mr. Ramon    male
# 631                 1       1  Barkworth, Mr. Algernon Henry Wilson    male
# 645                 1       3                Baclini, Miss. Eugenie  female
# 756                 1       2             Hamalainen, Master. Viljo    male
# 804                 1       3       Thomas, Master. Assad Alexander    male
# 832                 1       2       Richards, Master. George Sibley    male
# 852                 0       3                   Svensson, Mr. Johan    male
#
#                Age  SibSp  Parch    Ticket      Fare Embarked
# PassengerId
# 79            0.83      0      2    248738   29.0000        S
# 97           71.00      0      0  PC 17754   34.6542        C
# 117          70.50      0      0    370369    7.7500        Q
# 306           0.92      1      2    113781  151.5500        S
# 470           0.75      2      1      2666   19.2583        C
# 494          71.00      0      0  PC 17609   49.5042        C
# 631          80.00      0      0     27042   30.0000        S
# 645           0.75      2      1      2666   19.2583        C
# 756           0.67      1      1    250649   14.5000        S
# 804           0.42      0      1      2625    8.5167        C
# 832           0.83      1      1     29106   18.7500        S
# 852          74.00      0      0    347060    7.7750        S

# %%
df.isnull().any(axis=0).head()
# Out:
# Survived    False
# Pclass      False
# Name        False
# Sex         False
# Age         False
# dtype: bool

# %%
# get all rows with missing values (if any)
df[df.isnull().any(axis=1)]
# Out:
#              Survived  Pclass  \
# PassengerId
# 6                   0       3
# 18                  1       2
# 20                  1       3
# 27                  0       3
# 29                  1       3
# 30                  0       3
# 32                  1       1
# 33                  1       3
# 37                  1       3
# 43                  0       3
# 46                  0       3
# 47                  0       3
# 48                  1       3
# 49                  0       3
# 56                  1       1
# 62                  1       1
# 65                  0       1
# 66                  1       3
# 77                  0       3
# 78                  0       3
# 83                  1       3
# 88                  0       3
# 96                  0       3
# 102                 0       3
# 108                 1       3
# 110                 1       3
# 122                 0       3
# 127                 0       3
# 129                 1       3
# 141                 0       3
# 155                 0       3
# 159                 0       3
# 160                 0       3
# 167                 1       1
# 169                 0       1
# 177                 0       3
# 181                 0       3
# 182                 0       2
# 186                 0       1
# 187                 1       3
# 197                 0       3
# 199                 1       3
# 202                 0       3
# 215                 0       3
# 224                 0       3
# 230                 0       3
# 236                 0       3
# 241                 0       3
# 242                 1       3
# 251                 0       3
# 257                 1       1
# 261                 0       3
# 265                 0       3
# 271                 0       1
# 275                 1       3
# 278                 0       2
# 285                 0       1
# 296                 0       1
# 299                 1       1
# 301                 1       3
# 302                 1       3
# 304                 1       2
# 305                 0       3
# 307                 1       1
# 325                 0       3
# 331                 1       3
# 335                 1       1
# 336                 0       3
# 348                 1       3
# 352                 0       1
# 355                 0       3
# 359                 1       3
# 360                 1       3
# 365                 0       3
# 368                 1       3
# 369                 1       3
# 376                 1       1
# 385                 0       3
# 389                 0       3
# 410                 0       3
# 411                 0       3
# 412                 0       3
# 414                 0       2
# 416                 0       3
# 421                 0       3
# 426                 0       3
# 429                 0       3
# 432                 1       3
# 445                 1       3
# 452                 0       3
# 455                 0       3
# 458                 1       1
# 460                 0       3
# 465                 0       3
# 467                 0       2
# 469                 0       3
# 471                 0       3
# 476                 0       1
# 482                 0       2
# 486                 0       3
# 491                 0       3
# 496                 0       3
# 498                 0       3
# 503                 0       3
# 508                 1       1
# 512                 0       3
# 518                 0       3
# 523                 0       3
# 525                 0       3
# 528                 0       1
# 532                 0       3
# 534                 1       3
# 539                 0       3
# 548                 1       2
# 553                 0       3
# 558                 0       1
# 561                 0       3
# 564                 0       3
# 565                 0       3
# 569                 0       3
# 574                 1       3
# 579                 0       3
# 585                 0       3
# 590                 0       3
# 594                 0       3
# 597                 1       2
# 599                 0       3
# 602                 0       3
# 603                 0       1
# 612                 0       3
# 613                 1       3
# 614                 0       3
# 630                 0       3
# 634                 0       1
# 640                 0       3
# 644                 1       3
# 649                 0       3
# 651                 0       3
# 654                 1       3
# 657                 0       3
# 668                 0       3
# 670                 1       1
# 675                 0       2
# 681                 0       3
# 693                 1       3
# 698                 1       3
# 710                 1       3
# 712                 0       1
# 719                 0       3
# 728                 1       3
# 733                 0       2
# 739                 0       3
# 740                 0       3
# 741                 1       1
# 761                 0       3
# 767                 0       1
# 769                 0       3
# 774                 0       3
# 777                 0       3
# 779                 0       3
# 784                 0       3
# 791                 0       3
# 793                 0       3
# 794                 0       1
# 816                 0       1
# 826                 0       3
# 827                 0       3
# 829                 1       3
# 830                 1       1
# 833                 0       3
# 838                 0       3
# 840                 1       1
# 847                 0       3
# 850                 1       1
# 860                 0       3
# 864                 0       3
# 869                 0       3
# 879                 0       3
# 889                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 6                                             Moran, Mr. James    male   NaN
# 18                                Williams, Mr. Charles Eugene    male   NaN
# 20                                     Masselmani, Mrs. Fatima  female   NaN
# 27                                     Emir, Mr. Farred Chehab    male   NaN
# 29                               O'Dwyer, Miss. Ellen "Nellie"  female   NaN
# 30                                         Todoroff, Mr. Lalio    male   NaN
# 32              Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN
# 33                                    Glynn, Miss. Mary Agatha  female   NaN
# 37                                            Mamee, Mr. Hanna    male   NaN
# 43                                         Kraeff, Mr. Theodor    male   NaN
# 46                                    Rogers, Mr. William John    male   NaN
# 47                                           Lennon, Mr. Denis    male   NaN
# 48                                   O'Driscoll, Miss. Bridget  female   NaN
# 49                                         Samaan, Mr. Youssef    male   NaN
# 56                                           Woolner, Mr. Hugh    male   NaN
# 62                                         Icard, Miss. Amelie  female  38.0
# 65                                       Stewart, Mr. Albert A    male   NaN
# 66                                    Moubarek, Master. Gerios    male   NaN
# 77                                           Staneff, Mr. Ivan    male   NaN
# 78                                    Moutal, Mr. Rahamin Haim    male   NaN
# 83                              McDermott, Miss. Brigdet Delia  female   NaN
# 88                               Slocovski, Mr. Selman Francis    male   NaN
# 96                                 Shorney, Mr. Charles Joseph    male   NaN
# 102                           Petroff, Mr. Pastcho ("Pentcho")    male   NaN
# 108                                     Moss, Mr. Albert Johan    male   NaN
# 110                                        Moran, Miss. Bertha  female   NaN
# 122                                 Moore, Mr. Leonard Charles    male   NaN
# 127                                        McMahon, Mr. Martin    male   NaN
# 129                                          Peter, Miss. Anna  female   NaN
# 141                              Boulos, Mrs. Joseph (Sultana)  female   NaN
# 155                                      Olsen, Mr. Ole Martin    male   NaN
# 159                                        Smiljanic, Mr. Mile    male   NaN
# 160                                 Sage, Master. Thomas Henry    male   NaN
# 167                     Chibnall, Mrs. (Edith Martha Bowerman)  female   NaN
# 169                                        Baumann, Mr. John D    male   NaN
# 177                              Lefebre, Master. Henry Forbes    male   NaN
# 181                               Sage, Miss. Constance Gladys  female   NaN
# 182                                           Pernot, Mr. Rene    male   NaN
# 186                                      Rood, Mr. Hugh Roscoe    male   NaN
# 187            O'Brien, Mrs. Thomas (Johanna "Hannah" Godfrey)  female   NaN
# 197                                        Mernagh, Mr. Robert    male   NaN
# 199                           Madigan, Miss. Margaret "Maggie"  female   NaN
# 202                                        Sage, Mr. Frederick    male   NaN
# 215                                        Kiernan, Mr. Philip    male   NaN
# 224                                       Nenkoff, Mr. Christo    male   NaN
# 230                                    Lefebre, Miss. Mathilde  female   NaN
# 236                               Harknett, Miss. Alice Phoebe  female   NaN
# 241                                      Zabour, Miss. Thamine  female   NaN
# 242                             Murphy, Miss. Katherine "Kate"  female   NaN
# 251                                     Reed, Mr. James George    male   NaN
# 257                             Thorne, Mrs. Gertrude Maybelle  female   NaN
# 261                                          Smith, Mr. Thomas    male   NaN
# 265                                         Henry, Miss. Delia  female   NaN
# 271                                      Cairns, Mr. Alexander    male   NaN
# 275                                 Healy, Miss. Hanora "Nora"  female   NaN
# 278                                Parkes, Mr. Francis "Frank"    male   NaN
# 285                                 Smith, Mr. Richard William    male   NaN
# 296                                          Lewy, Mr. Ervin G    male   NaN
# 299                                      Saalfeld, Mr. Adolphe    male   NaN
# 301                   Kelly, Miss. Anna Katherine "Annie Kate"  female   NaN
# 302                                         McCoy, Mr. Bernard    male   NaN
# 304                                        Keane, Miss. Nora A  female   NaN
# 305                          Williams, Mr. Howard Hugh "Harry"    male   NaN
# 307                                    Fleming, Miss. Margaret  female   NaN
# 325                                   Sage, Mr. George John Jr    male   NaN
# 331                                         McCoy, Miss. Agnes  female   NaN
# 335          Frauenthal, Mrs. Henry William (Clara Heinshei...  female   NaN
# 336                                         Denkoff, Mr. Mitto    male   NaN
# 348                  Davison, Mrs. Thomas Henry (Mary E Finck)  female   NaN
# 352                     Williams-Lambert, Mr. Fletcher Fellows    male   NaN
# 355                                          Yousif, Mr. Wazli    male   NaN
# 359                                       McGovern, Miss. Mary  female   NaN
# 360                          Mockler, Miss. Helen Mary "Ellie"  female   NaN
# 365                                        O'Brien, Mr. Thomas    male   NaN
# 368                             Moussa, Mrs. (Mantoura Boulos)  female   NaN
# 369                                        Jermyn, Miss. Annie  female   NaN
# 376                      Meyer, Mrs. Edgar Joseph (Leila Saks)  female   NaN
# 385                                     Plotcharsky, Mr. Vasil    male   NaN
# 389                                       Sadlier, Mr. Matthew    male   NaN
# 410                                         Lefebre, Miss. Ida  female   NaN
# 411                                         Sdycoff, Mr. Todor    male   NaN
# 412                                            Hart, Mr. Henry    male   NaN
# 414                             Cunningham, Mr. Alfred Fleming    male   NaN
# 532              0      0                2641    7.2292        C
# 534              0      2                2668   22.3583        C
# 539              0      0              364498   14.5000        S
# 548              0      0       SC/PARIS 2146   13.8625        C
# 553              0      0              330979    7.8292        Q
# 558              0      0            PC 17757  227.5250        C
# 561              0      0              372622    7.7500        Q
# 564              0      0     SOTON/OQ 392082    8.0500        S
# 565              0      0   SOTON/O.Q. 392087    8.0500        S
# 569              0      0                2686    7.2292        C
# 574              0      0               14312    7.7500        Q
# 579              1      0                2689   14.4583        C
# 585              0      0                3411    8.7125        C
# 590              0      0          A./5. 3235    8.0500        S
# 594              0      2              364848    7.7500        Q
# 597              0      0              248727   33.0000        S
# 599              0      0                2664    7.2250        C
# 602              0      0              349214    7.8958        S
# 603              0      0              113796   42.4000        S
# 612              0      0  SOTON/O.Q. 3101305    7.0500        S
# 613              1      0              367230   15.5000        Q
# 614              0      0              370377    7.7500        Q
# 630              0      0              334912    7.7333        Q
# 634              0      0              112052    0.0000        S
# 640              1      0              376564   16.1000        S
# 644              0      0                1601   56.4958        S
# 649              0      0       S.O./P.P. 751    7.5500        S
# 651              0      0              349221    7.8958        S
# 654              0      0              330919    7.8292        Q
# 657              0      0              349223    7.8958        S
# 668              0      0              312993    7.7750        S
# 670              1      0               19996   52.0000        S
# 675              0      0              239856    0.0000        S
# 681              0      0              330935    8.1375        Q
# 693              0      0                1601   56.4958        S
# 698              0      0               35852    7.7333        Q
# 710              1      1                2661   15.2458        C
# 712              0      0              113028   26.5500        S
# 719              0      0               36568   15.5000        Q
# 728              0      0               36866    7.7375        Q
# 733              0      0              239855    0.0000        S
# 739              0      0              349201    7.8958        S
# 740              0      0              349218    7.8958        S
# 741              0      0               16988   30.0000        S
# 761              0      0              358585   14.5000        S
# 767              0      0              112379   39.6000        C
# 769              1      0              371110   24.1500        Q
# 774              0      0                2674    7.2250        C
# 777              0      0              383121    7.7500        Q
# 779              0      0               36865    7.7375        Q
# 784              1      2          W./C. 6607   23.4500        S
# 791              0      0               12460    7.7500        Q
# 793              8      2            CA. 2343   69.5500        S
# 794              0      0            PC 17600   30.6958        C
# 816              0      0              112058    0.0000        S
# 826              0      0              368323    6.9500        Q
# 827              0      0                1601   56.4958        S
# 829              0      0              367228    7.7500        Q
# 830              0      0              113572   80.0000      NaN
# 833              0      0                2671    7.2292        C
# 838              0      0              392092    8.0500        S
# 840              0      0               11774   29.7000        C
# 847              8      2            CA. 2343   69.5500        S
# 850              1      0               17453   89.1042        C
# 860              0      0                2629    7.2292        C
# 864              8      2            CA. 2343   69.5500        S
# 869              0      0              345777    9.5000        S
# 879              0      0              349217    7.8958        S
# 889              1      2          W./C. 6607   23.4500        S

# %% [markdown]
# ### Summarising Groups in the DataFrame

# %%
# Nummber of non-null unique Pclass values
df['Pclass'].nunique()
# Out:
# 3

# %%
# What are the unique values for Pclass
df['Pclass'].unique()
# Out:
# array([1, 3, 2], dtype=int64)

# %%
# How many samples are there for each Pclass?

# Method 1
# get the Pclass column and count each value in the column
df['Pclass'].value_counts()
# Out:
# 3    354
# 1    184
# 2    173
# Name: Pclass, dtype: int64

# %%
# How many samples are there for each Pclass?

# Method 2
# get the Pclass column and another column for counting (Name in this case)  
# group the data by Pclass
# count the PassengerId in each group of Pclass
df[['Pclass', 'Name']].groupby('Pclass').count()
# Out:
#         Name
# Pclass
# 1        184
# 2        173
# 3        354

# %%
# How many male and female passengers?

# get the Sex column and count each value in the column
df['Sex'].value_counts()
# Out:
# male      452
# female    259
# Name: Sex, dtype: int64

# %%
# How many male and female passengers in each Pclass?

# 1. group the data by Pclass
# 2. count each value in the Sex column (in each Pclass group)
df.groupby('Pclass')['Sex'].value_counts()
# Out:
# Pclass  Sex
# 1       male      101
#         female     83
# 2       male       99
#         female     74
# 3       male      252
#         female    102
# Name: Sex, dtype: int64

# %%
# the average age in each Pclass

# Method 1
# 1. group the data by Pclass
# 2. find the average value of Age column (in each Pclass group)
df.groupby('Pclass')['Age'].mean()
# Out:
# Pclass
# 1    38.105543
# 2    29.877630
# 3    25.149492
# Name: Age, dtype: float64

# %%
type(df.groupby('Pclass')['Age'].mean())
# Out:
# pandas.core.series.Series

# %%
# the average age in each Pclass

# Method 2
# 1. get the Pclass and Age columns
# 2. group the data by Pclass
# 2. find the average value of Age column (in each Pclass group)
df[['Pclass', 'Age']].groupby('Pclass').mean()
# Out:
#               Age
# Pclass
# 1       38.105543
# 2       29.877630
# 3       25.149492

# %%
type(df[['Pclass', 'Age']].groupby('Pclass').mean())
# Out:
# pandas.core.frame.DataFrame

# %%
# the average age of each gender group in each Pclass
df[['Pclass', 'Age', 'Sex']].groupby(['Pclass', 'Sex']).mean()
# Out:
#                      Age
# Pclass Sex
# 1      female  34.240964
#        male    41.281386
# 2      female  28.722973
#        male    30.740707
# 3      female  21.750000
#        male    26.525476

# %% [markdown]
# Here is a quick reference summary table of some common functions.
#
# ![buit-in.PNG](attachment:buit-in.PNG)
#
# <font size = 1> image source: https://pandas.pydata.org/pandas-docs/stable/getting_started/basics.html </font>

# %% [markdown]
# ## 2. Visualizing the data

# %% [markdown]
# ### Matplotlib Magic Function
# Run the following magic function to allow displaying the plot within the cell

# %%
# %matplotlib inline

# %% [markdown]
# ### The Pandas Plot Function
#
# Pandas has a built in `.plot()` function as part of the DataFrame class. It has several key parameters:
#
# - kind: ‘line’, ‘bar’, ’pie’,’scatter’, etc.
# - title: The string title of the plot
# - legend: a boolean value to display or hide the legend
# - figsize : a tuple (width, height) in inches
#
# See https://pandas.pydata.org/pandas-docs/version/0.23/generated/pandas.DataFrame.plot.html for more information.
#
#
# The major use cases for `.plot()` is when you have a meaningful index, which usually happens in two situations:
# - You have just done a `.value_counts()` or a `.groupby()`
# - You have used `.set_index`, probably with dates
#
# These are fairly straightforward to use. Let us do some examples using `.plot()`.

# %% [markdown]
# ### Bar charts

# %% [markdown]
# #### Plot the no. of passengers in each gender group

# %%
df['Sex'].value_counts()
# Out:
# male      452
# female    259
# Name: Sex, dtype: int64

# %%
# Plot the no. of passengers in each gender group

df['Sex'].value_counts().plot(kind='bar', 
                              title='No. of Passengers in each Gender Group',
                              figsize=(6, 4))
# Out:
# <AxesSubplot:title={'center':'No. of Passengers in each Gender Group'}>

# %% [markdown]
# #### Plot the no. of passengers in each pclass

# %%
df[['Pclass', 'Name']].groupby('Pclass').count()
# Out:
#         Name
# Pclass
# 1        184
# 2        173
# 3        354

# %%
# plot the no. of passengers in each pclass

df[['Pclass', 'Name']].groupby('Pclass').count().plot(kind='bar', 
                                                             title='No. of Passengers in each Pclass', 
                                                             legend=False,
                                                             figsize=(6, 4))
# Out:
# <AxesSubplot:title={'center':'No. of Passengers in each Pclass'}, xlabel='Pclass'>

# %% [markdown]
# #### Plot the mean age of each pclass

# %%
df.groupby('Pclass')['Age'].mean()
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %%
# plot the mean age of each pclass

df.groupby('Pclass')['Age'].mean().plot(kind='bar', 
                                        title='Mean Age in each Pclass', 
                                        figsize=(6, 4))
# Out:
# <AxesSubplot:title={'center':'Mean Age in each Pclass'}, xlabel='Pclass'>

# %% [markdown]
# #### Plot the no. of survived and dead

# %%
df['Survived'].value_counts()
# Out:
# 0    423
# 1    288
# Name: Survived, dtype: int64

# %%
new_df = df['Survived'] # create a new dataframe with the Survived column
new_df = new_df.replace({0: 'Dead', 1: 'Survived'}) # relace 0 with 'Dead', 1 with 'Survived'
new_df.value_counts()
# Out:
# Dead        423
# Survived    288
# Name: Survived, dtype: int64

# %%
# plot the no. of Survived and Dead

new_df.value_counts().plot(kind = 'bar', 
                           title='Number of Survived and Dead',
                           figsize=(6, 4))
# Out:
# <AxesSubplot:title={'center':'Number of Survived and Dead'}>

# %% [markdown]
# ### Line charts

# %% [markdown]
# #### Plot the average age vs. no. of siblings and spouses traveling with the passenger

# %%
df[['Age', 'SibSp']].groupby(['SibSp']).mean()
# Out:
#              Age
# SibSp
# 0      31.318230
# 1      30.134176
# 2      22.620000
# 3      13.916667
# 4       7.055556
# 5      10.200000

# %%
# plot the average age vs no. of siblings and spouses traveling with the passenger
df[['Age', 'SibSp']].groupby(['SibSp']).mean().plot(kind = 'line', 
                                                    title='Average Age vs No. of Siblings and Spouses',
                                                    figsize=(6, 4))
# Out:
# <AxesSubplot:title={'center':'Average Age vs No. of Siblings and Spouses'}, xlabel='SibSp'>

# %% [markdown]
# #### Plot more than one line in the chart

# %%
# average age and average fare for each no. of siblings and spouses

df[['Age', 'SibSp', 'Fare']].groupby(['SibSp']).mean()
# Out:
#              Age       Fare
# SibSp
# 0      31.318230  27.934620
# 1      30.134176  45.680199
# 2      22.620000  55.236996
# 3      13.916667  83.389583
# 4       7.055556  31.855556
# 5      10.200000  46.900000

# %%
# plot the 
# - average age vs no. of siblings and spouses traveling with the passenger
# - average fare vs no. of siblings and spouses traveling with the passenger

df[['Age', 'SibSp', 'Fare']].groupby(['SibSp']).mean().plot(kind = 'line', 
                                                            title='Averge Age and Average Fare',
                                                            figsize=(6, 4))

# %% [markdown]
# ### Scatterplots

# %% [markdown]
# #### Scatterplot of Fare vs Age

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 7                   0       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
#
#              SibSp  Parch            Ticket     Fare Embarked
# PassengerId
# 2                1      0          PC 17599  71.2833        C
# 3                0      0  STON/O2. 3101282   7.9250        S
# 4                1      0            113803  53.1000        S
# 5                0      0            373450   8.0500        S
# 7                0      0             17463  51.8625        S

# %%
# Scatterplot of Fare vs Age
df.plot(x='Age',
        y='Fare',
        kind = 'scatter', 
        title='Fare vs Age',
        figsize=(6, 4))
# Out:
# <AxesSubplot:title={'center':'Fare vs Age'}, xlabel='Age', ylabel='Fare'>
